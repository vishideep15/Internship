# %% [markdown]
# 1.Write a python program to display all the header tags from‘en.wikipedia.org/wiki/Main_Page’.

# %%
import  requests
from  bs4 import BeautifulSoup

url = requests.get('https://en.wikipedia.org/wiki/Main_Page')
soup = BeautifulSoup(url.text, 'html.parser')
data = soup.find_all(['h1', 'h2','h3','h4','h5','h6'])
for i in data:
    print(i)
# Out:
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
# <h2 class="mp-h2" id="mp-tfl-h2"><span id="From_today.27s_featured_list"></span><span class="mw-headline" id="From_today's_featured_list">From today's featured list</span></h2>
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
# ...

# %% [markdown]
# 2. Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of
# release).

# %%
#importing the required libraries
from bs4 import BeautifulSoup
import requests
from time import sleep
from random import randint
import pandas as pd
import numpy as np

# %%
page=requests.get("https://www.imdb.com/search/title/?groups=top_100&ref_=adv_prv")
page
# Out:
# <Response [200]>

# %%
pages = np.arange(1, 101, 50)
pages
# Out:
# array([ 1, 51])

# %%
headers = {'Accept-Language': 'en-US, en;q=0.5'}

# %%
titles = []
years = []
imdb_ratings = []

# %%
for page in pages:
    page = requests.get('https://www.imdb.com/search/title/?groups=top_1000&start=' + str(page) + '&ref_=adv_nxt', headers=headers)
    soup = BeautifulSoup(page.text, 'html.parser')
    
    movie_div = soup.find_all('div', class_='lister-item mode-advanced')
    sleep(randint(2,10))
        
for container in movie_div:
        name = container.h3.a.text
        titles.append(name)
        
        year = container.h3.find('span', class_='lister-item-year').text
        years.append(year)
        
        imdb = float(container.strong.text)
        imdb_ratings.append(imdb)

# %%
movies = pd.DataFrame({'movie':titles,
                       'year':years,
                       'imdb_rating':imdb_ratings})

movies
# Out:
#                                     movie    year  imdb_rating
# 0                              Braveheart  (1995)          8.3
# 1                           Spirited Away  (2001)          8.6
# 2   Eternal Sunshine of the Spotless Mind  (2004)          8.3
# 3                                The Hunt  (2012)          8.3
# 4          The Good, the Bad and the Ugly  (1966)          8.8
# ..                                    ...     ...          ...
# 95                    There Will Be Blood  (2007)          8.2
# 96                           True Romance  (1993)          7.9
# 97                         Reservoir Dogs  (1992)          8.3
# 98                           The Irishman  (2019)          7.8
# 99                           Ghostbusters  (1984)          7.8
#
# [100 rows x 3 columns]

# %% [markdown]
# 3.Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year
# of release).

# %%
from bs4 import BeautifulSoup
import requests
import re

# Download IMDB's Top 250 data
url = 'https://www.imdb.com/india/top-rated-indian-movies'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []

for index in range(0, len(movies)):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') ')
# Out:
# 1 - Nayakan (1987)
# 2 - Anbe Sivam (2003)
# 3 - Pariyerum Perumal (2018)
# 4 - Golmaal (1979)
# 5 - C/o Kancharapalem (2018)
# 6 - Apur Sansar (1959)
# 7 - Manichitrathazhu (1993)
# 8 - Kireedam (1989)
# 9 - Natsamrat (2016)
# 1 -  Pather Panchali (1955)
# 11 - 96 (2018)
# 12 - Thevar Magan (1992)
# 13 - Black Friday (2004)
# 14 - Kumbalangi Nights (2019)
# 15 - Visaaranai (2015)
# 16 - 3 Idiots (2009)
# 17 - Soorarai Pottru (2020)
# 18 - Jersey (2019)
# 19 - Taare Zameen Par (2007)
# 20 - Drishyam 2 (2021)
# 21 - Asuran (2019)
# 22 - Thalapathi (1991)
# 23 - Kaithi (2019)
# 24 - Dangal (2016)
# 25 - Sarpatta Parambarai (2021)
# 26 - Devasuram (1993)
# 27 - Ratsasan (2018)
# 28 - Aparajito (1956)
# 29 - Jaane Bhi Do Yaaro (1983)
# 30 - Pyaasa (1957)
# 31 - Peranbu (2018)
# 32 - Vada Chennai (2018)
# 33 - Guide (1965)
# 34 - Thani Oruvan (2015)
# 35 - Kannathil Muthamittal (2002)
# 36 - Chupke Chupke (1975)
# 37 - Iruvar (1997)
# 38 - Spadikam (1995)
# ...

# %% [markdown]
# 4. Write a python program to scrap book name, author name, genre and book review of any 5 books from
# ‘www.bookpage.com'

# %%
#importing the required libraries
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://bookpage.com/reviews")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang=\'en\' xmlns:fb=\'http://www.facebook.com/2008/fbml\' xmlns:og=\'http://opengraphprotocol.org/schema/\'>\n<head>\n<title>Book Reviews | BookPage</title>\n<meta name="description" content="Book recommendations of the best new books by genre and more.">\n<meta name="keywords" content="book reviews, books and literature, writing and writers">\n<link rel="canonical" href="https://bookpage.com/reviews">\n<meta property="og:site_name" content="BookPage.com">\n<meta property="og:title" content="Book Reviews">\n<meta property="og:description" content="Book recommendations of the best new books by genre and more.">\n<meta property="og:type" content="website">\n<meta property="og:url" content="https://bookpage.com/reviews">\n<meta property="og:image" content="//www.bookpage.com/default_image.jpg">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:site" content="@bookpage">\n<meta name="twitter:creator" content="@bookpage">\n<meta name="robots" con
# ...

# %%
Soup=BeautifulSoup(page.content)
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Book Reviews | BookPage</title>
# <meta content="Book recommendations of the best new books by genre and more." name="description"/>
# <meta content="book reviews, books and literature, writing and writers" name="keywords"/>
# <link href="https://bookpage.com/reviews" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Book Reviews" property="og:title"/>
# <meta content="Book recommendations of the best new books by genre and more." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://bookpage.com/reviews" property="og:url"/>
# <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@bookpage" name="twitter:site"/>
# <meta content="@bookpage" name="twitter:creator"/>
# ...

# %%
name=Soup.find_all("h4",class_="italic")
name
# Out:
# [<h4 class="italic">
#  <a href="/reviews/26568-seth-rogen-yearbook-audio">Yearbook</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26609-nancy-springer-enola-holmes-black-barouche-ya">Enola Holmes and the Black Barouche</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26566-john-green-anthropocene-reviewed-audio">The Anthropocene Reviewed</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26564-clint-smith-how-word-passed-audio"> <span style="font-style:normal;">★ </span>How the Word Is Passed</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26569-tarana-burke-you-are-your-best-thing-audio"> <span style="font-style:normal;">★ </span>You Are Your Best Thing</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26606-rosalyn-eves-beyond-mapped-stars-ya">Beyond the Mapped Stars</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26572-jaime-cortez-gordo-fiction"> <span style="font-style:normal;">★ </span>Gordo</a>
#  </h4>,
# ...

# %%
book_name=[]
for i in name:
    book_name.append(i.text.replace("\n",""))
    
book_name
# Out:
# ['Yearbook',
#  'Enola Holmes and the Black Barouche',
#  'The Anthropocene Reviewed',
#  ' ★ How the Word Is Passed',
#  ' ★ You Are Your Best Thing',
#  'Beyond the Mapped Stars',
#  ' ★ Gordo',
#  ' ★ Two-Way Mirror',
#  'Forestborn',
#  'Velvet Was the Night']

# %%
name=Soup.find_all("p",class_="sans bold")
name
# Out:
# [<p class="sans bold">
#  Seth Rogen, Cast
#  </p>,
#  <p class="sans bold">
#  Nancy Springer
#  </p>,
#  <p class="sans bold">
#  John Green
#  </p>,
#  <p class="sans bold">
#  Clint Smith
#  </p>,
#  <p class="sans bold">
#  Tarana Burke, Brené Brown, Cast
#  </p>,
#  <p class="sans bold">
#  Rosalyn Eves
#  </p>,
#  <p class="sans bold">
#  Jaime Cortez
#  </p>,
#  <p class="sans bold">
#  Fiona Sampson
#  </p>,
#  <p class="sans bold">
#  Elayne Audrey Becker
#  </p>,
#  <p class="sans bold">
#  Silvia Moreno-Garcia
#  </p>]

# %%
aname=[]
for i in name:
    aname.append(i.text.replace("\n",""))
    
aname
# Out:
# ['Seth Rogen, Cast',
#  'Nancy Springer',
#  'John Green',
#  'Clint Smith',
#  'Tarana Burke, Brené Brown, Cast',
#  'Rosalyn Eves',
#  'Jaime Cortez',
#  'Fiona Sampson',
#  'Elayne Audrey Becker',
#  'Silvia Moreno-Garcia']

# %%
genre=Soup.find_all("p", "genre-links hidden-phone")
genre
# Out:
# [<p class="genre-links hidden-phone">
#  <a href="/search?book_genre=audio">Audio</a>
#   /
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
#  <a href="/search?book_genre=humor">Humor</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=ya">YA</a>
#   /
#  <a href="/search?book_genre=ya_fiction">YA Fiction</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=audio">Audio</a>
#   /
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
#  <a href="/search?book_genre=essays">Essays</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=audio">Audio</a>
#   /
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
#  <a href="/search?book_genre=african_american_history">African American History</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=audio">Audio</a>
#   /
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
# ...

# %%
Genre=[]
for i in genre:
    Genre.append(i.text.replace("\n",""))
    
Genre
# Out:
# ['Audio / Nonfiction / Humor',
#  'YA / YA Fiction',
#  'Audio / Nonfiction / Essays',
#  'Audio / Nonfiction / African American History',
#  'Audio / Nonfiction / Essays',
#  'YA / YA Fiction',
#  'Fiction / Short Stories',
#  'Nonfiction / Biography / Literary History',
#  'YA / YA Fiction',
#  'Fiction / Noir']

# %%
review=Soup.find_all("p",class_="excerpt")
review
# Out:
# [<p class="excerpt">
#  Seth Rogen’s audiobook is a blast, with guest appearances from Dan Aykroyd, Tommy Chong, Snoop Dogg, Michel Gondry, Billy Idol and more.
#  </p>,
#  <p class="excerpt">
#  </p>,
#  <p class="excerpt">
#  With storytelling skills from years as a podcaster and YouTuber, John Green makes even the most obscure topics compelling in his audiobook.
#  </p>,
#  <p class="excerpt">
#  Clint Smith’s narration of <strong>How the Word Is Passed</strong> models the courage and fortitude required to face this timely reckoning with America’s past.
#  </p>,
#  <p class="excerpt">
#  Tarana Burke and Brené Brown demonstrate the power of bringing one’s authentic self to the work of deconstructing oppressive power structures.
#  </p>,
#  <p class="excerpt">
#  Rosalyn Eves’ <b>Beyond the Mapped Stars</b> blends fiction and fact to create an adventure that doesn’t shy away from difficult topics.</p>,
#  <p class="excerpt">
# ...

# %%
Review=[]
for i in review:
    Review.append(i.text.replace("\n",""))

Review
# Out:
# ['Seth Rogen’s audiobook is a blast, with guest appearances from Dan Aykroyd, Tommy Chong, Snoop Dogg, Michel Gondry, Billy Idol and more.',
#  '',
#  'With storytelling skills from years as a podcaster and YouTuber, John Green makes even the most obscure topics compelling in his audiobook.',
#  'Clint Smith’s narration of How the Word Is Passed models the courage and fortitude required to face this timely reckoning with America’s past.',
#  'Tarana Burke and Brené Brown demonstrate the power of bringing one’s authentic self to the work of deconstructing oppressive power structures.',
#  'Rosalyn Eves’ Beyond the Mapped Stars blends fiction and fact to create an adventure that doesn’t shy away from difficult topics.',
#  'As in John Steinbeck’s The Grapes of Wrath, the characters in Gordo are often poor in economic terms but lead richly complex lives.',
# ...

# %%
import pandas as pd
Books=pd.DataFrame({})
Books['Name']=book_name
Books['Author_name']=aname
Books['Genre']=Genre
Books['Review']=Review

Books.head()  # no review available for the 2nd entry
# Out:
#                                   Name                      Author_name  \
# 0                             Yearbook                 Seth Rogen, Cast
# 1  Enola Holmes and the Black Barouche                   Nancy Springer
# 2            The Anthropocene Reviewed                       John Green
# 3             ★ How the Word Is Passed                      Clint Smith
# 4            ★ You Are Your Best Thing  Tarana Burke, Brené Brown, Cast
#
#                                            Genre  \
# 0                     Audio / Nonfiction / Humor
# 1                                YA / YA Fiction
# 2                    Audio / Nonfiction / Essays
# 3  Audio / Nonfiction / African American History
# 4                    Audio / Nonfiction / Essays
#
#                                               Review
# 0  Seth Rogen’s audiobook is a blast, with guest ...
# 1
# 2  With storytelling skills from years as a podca...
# 3  Clint Smith’s narration of How the Word Is Pas...
# ...

# %% [markdown]
# 7.Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The
# scraped data should include Product Name, Price, Image URL and Average Rating.

# %%
#importing the required libraries
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://www.amazon.in/s?k=phones+under+20000&crid=142DGA1ID1VVZ&sprefix=phones+under+%2Caps%2C338&ref=nb_sb_ss_ts-doa-p_10_13")
page
# Out:
# <Response [503]>

# %%
##Response is 503 instead of 200 so did not scrap the data.

# %% [markdown]
# 8.Write a python program to extract information about the local weather from the National Weather Service
# website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day
# extended forecast display for the city. The data should include period, short description, temperature and
# description.

# %%
#importing the required libraries
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YSiGKI4zZPY")
page
# Out:
# <Response [200]>

# %%
page.content   #display scrapped data
# Out:
# b'<!DOCTYPE html>\n<html class="no-js">\n    <head>\n        <!-- Meta -->\n        <meta name="viewport" content="width=device-width">\n        <link rel="schema.DC" href="http://purl.org/dc/elements/1.1/" /><title>National Weather Service</title><meta name="DC.title" content="National Weather Service" /><meta name="DC.description" content="NOAA National Weather Service National Weather Service" /><meta name="DC.creator" content="US Department of Commerce, NOAA, National Weather Service" /><meta name="DC.date.created" scheme="ISO8601" content="" /><meta name="DC.language" scheme="DCTERMS.RFC1766" content="EN-US" /><meta name="DC.keywords" content="weather, National Weather Service" /><meta name="DC.publisher" content="NOAA\'s National Weather Service" /><meta name="DC.contributor" content="National Weather Service" /><meta name="DC.rights" content="http://www.weather.gov/disclaimer.php" /><meta name="rating" content="General" /><meta name="robots" content="index,follow" />\n\n      
# ...

# %%
 soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")
forecast_items = seven_day.find_all(class_="tombstone-container")
tonight = forecast_items[0]
print(tonight.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Tonight
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Tonight: Partly cloudy, with a low around 57. Southwest wind 6 to 9 mph. " class="forecast-icon" src="newimages/medium/nsct.png" title="Tonight: Partly cloudy, with a low around 57. Southwest wind 6 to 9 mph. "/>
#  </p>
#  <p class="short-desc">
#   Partly Cloudy
#  </p>
#  <p class="temp temp-low">
#   Low: 57 °F
#  </p>
# </div>

# %%
period = tonight.find(class_="period-name").get_text()
short_desc = tonight.find(class_="short-desc").get_text()
temp = tonight.find(class_="temp").get_text()
print(period)
print(short_desc)
print(temp)
# Out:
# Tonight
# Partly Cloudy
# Low: 57 °F

# %%
img = tonight.find("img")
desc = img['title']
print(desc)
# Out:
# Tonight: Partly cloudy, with a low around 57. Southwest wind 6 to 9 mph.

# %%
period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]
periods
# Out:
# ['Tonight',
#  'Friday',
#  'FridayNight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday',
#  'SundayNight',
#  'Monday',
#  'MondayNight']

# %%
short_descs = [sd.get_text() for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]
print(short_descs)
print(temps)
print(descs)
# Out:
# ['Partly Cloudy', 'Mostly Sunnythen Haze', 'Haze thenMostly Clear', 'Sunny', 'Mostly Clearand Breezythen PartlyCloudy', 'Mostly Sunnythen Sunnyand Breezy', 'Mostly Clearand Breezythen PartlyCloudy', 'Mostly Sunny', 'Mostly Clear']
# ['Low: 57 °F', 'High: 76 °F', 'Low: 58 °F', 'High: 75 °F', 'Low: 57 °F', 'High: 73 °F', 'Low: 56 °F', 'High: 67 °F', 'Low: 55 °F']
# ...

# %%
import pandas as pd
weather = pd.DataFrame({
    "Period": periods,
    "Short_desc": short_descs,
    "Temp": temps,
    "Desc":descs
})
weather
# Out:
#           Period                               Short_desc         Temp  \
# 0        Tonight                            Partly Cloudy   Low: 57 °F
# 1         Friday                    Mostly Sunnythen Haze  High: 76 °F
# 2    FridayNight                    Haze thenMostly Clear   Low: 58 °F
# 3       Saturday                                    Sunny  High: 75 °F
# 4  SaturdayNight  Mostly Clearand Breezythen PartlyCloudy   Low: 57 °F
# 5         Sunday         Mostly Sunnythen Sunnyand Breezy  High: 73 °F
# 6    SundayNight  Mostly Clearand Breezythen PartlyCloudy   Low: 56 °F
# 7         Monday                             Mostly Sunny  High: 67 °F
# 8    MondayNight                             Mostly Clear   Low: 55 °F
#
#                                                 Desc
# 0  Tonight: Partly cloudy, with a low around 57. ...
# 1  Friday: Widespread haze between 3pm and 4pm. A...
# 2  Friday Night: Widespread haze between 7pm and ...
# ...

# %% [markdown]
# 9. Write a python program to scrape fresher job listings from ‘https://internshala.com/’. It should include job title,
# company name, CTC, and apply date.

# %%
#importing the required libraries
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://internshala.com/fresher-jobs")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml">\n    <head>\n        <meta http-equiv="X-UA-Compatible" content="IE=9" />\n        <meta charset="UTF-8" />\n        <meta name="viewport" content="width=device-width, initial-scale=1.0 user-scalable=0" />\n        <meta property="fb:app_id" content="272234782795210" />\n        <meta property="og:type" content="article" />\n                    <meta property="og:image:width" content="1200" />\n            <meta property="og:image:height" content="630" />\n                    <meta name="twitter:site" content="@Internshala" />\n                    <meta name="twitter:card" content="summary_large_image" />\n        \n        <meta name="twitter:creator" content="@internshala" />\n                <meta name="theme-color" content="#ffffff" />\n        <meta name="msapplication-navbutton-color" content="#ffffff"/>\n        <meta name="format-detection"
# ...

# %%
Soup=BeautifulSoup(page.content)   #scrape webpage
Soup
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
# <meta content="272234782795210" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="@Internshala" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@internshala" name="twitter:creator"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="#ffffff" name="msapplication-navbutton-color"/>
# <meta content="telephone=no" name="format-detection"/>
# <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" rel="preload" type="font/woff2"/>
# ...

# %%
job_title=Soup.find_all("div",class_="heading_4_5 profile")
job_title
# Out:
# [<div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/omni-sport-leader-fresher-jobs-in-hyderabad-at-decathlon-sport-india-private-limited1629355813">OMNI SPORT LEADER</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/executive-senior-executive-partnerships-fresher-jobs-in-multiple-locations-at-freecharge-payments-technology-private-limited1628770904">Executive/Senior Executive - Partnerships</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/executive-sales-fresher-jobs-in-multiple-locations-at-freecharge-payments-technology-private-limited1628770715">Executive - Sales</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/junior-operations-executive-fresher-jobs-in-gurgaon-at-freecharge-payments-technology-private-limited1628075825">Junior Operations Executive</a> </div>,
#  <div class="heading_4_5 profile">
# ...

# %%
Job_title=[]
for i in job_title:
    Job_title.append(i.text.replace("\n"," "))
    
Job_title
# Out:
# [' OMNI SPORT LEADER ',
#  ' Executive/Senior Executive - Partnerships ',
#  ' Executive - Sales ',
#  ' Junior Operations Executive ',
#  ' Student Success - Teacher ',
#  ' Supply Chain Executive ',
#  ' Game Developer ',
#  ' Associate - Digital Products ',
#  ' Program Impact In-charge (Science And Mathematics) ',
#  ' Software Engineer Trainee ',
#  ' Sales Executive ',
#  ' Digital Marketing Executive ',
#  ' Corporate Sales Manager ',
#  ' Software Developer ',
#  ' Executive Assistant To Director ',
#  ' C++ Embedded/Semiconductor Expert (SoC Modeling) ',
#  ' Mobile App Developer ',
#  ' Software Developer ',
#  ' Coding Teacher (Remote) ',
#  ' Validation Expert ',
#  ' Full Stack Developer ',
#  ' Business Development Associate ',
#  ' Content & E-commerce Management Executive ',
#  ' Business Development Specialist ',
#  ' Assistant Manager - Outreach & Events ',
#  ' Investor Pitch Deck - Content Writer ',
#  ' Full Stack Engineer (MERN) ',
# ...

# %%
company_name=Soup.find_all("div",class_="heading_6 company_name")
company_name
# Out:
# [<div class="heading_6 company_name">
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Decathlon%20Sport%20India%20Private%20Limited">
#                          Decathlon Sport India Private Limited                    </a>
#  </div>,
#  <div class="heading_6 company_name">
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Freecharge%20Payments%20Technology%20Private%20Limited">
#                          Freecharge Payments Technology Private Limited                    </a>
#  </div>,
#  <div class="heading_6 company_name">
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Freecharge%20Payments%20Technology%20Private%20Limited">
#                          Freecharge Payments Technology Private Limited                    </a>
#  </div>,
#  <div class="heading_6 company_name">
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Freecharge%20Payments%20Technology%20Private%20Limited">
# ...

# %%
Company_name=[]
for i in company_name:
    Company_name.append(i.text.replace("\n",""))
   ## Company_name.append(i.text.replace("'",""))
    
Company_name
# Out:
# ['                        Decathlon Sport India Private Limited                    ',
#  '                        Freecharge Payments Technology Private Limited                    ',
#  '                        Freecharge Payments Technology Private Limited                    ',
#  '                        Freecharge Payments Technology Private Limited                    ',
#  '                        Code A Block (KEDTech LLC)                    ',
#  '                        Serturner                    ',
#  '                        Cogent Web Services                    ',
#  '                        RocSearch                    ',
#  '                        Open Door Education                    ',
#  '                        Markytics                    ',
#  '                        1st In Class                    ',
#  '                        TradeVinder                    ',
#  '                        FinDestination                    ',
# ...

# %%
ctc=Soup.find_all("div",class_="item_body")
ctc
# Out:
# [<div class="item_body" id="start-date-first">
#  <span class="start_immediately_mobile">Starts </span>Immediately
#                          </div>,
#  <div class="item_body">
#  <i class="ic-16-currency-inr"></i>  3 - 4 LPA                                                    </div>,
#  <div class="item_body">18 Sep' 21</div>,
#  <div class="item_body" id="start-date-first">
#  <span class="start_immediately_mobile">Starts </span>Immediately
#                          </div>,
#  <div class="item_body">
#  <i class="ic-16-currency-inr"></i>  3 - 4.2 LPA                                                    </div>,
#  <div class="item_body">11 Sep' 21</div>,
#  <div class="item_body" id="start-date-first">
#  <span class="start_immediately_mobile">Starts </span>Immediately
#                          </div>,
#  <div class="item_body">
#  <i class="ic-16-currency-inr"></i>  3 - 3.5 LPA                                                    </div>,
#  <div class="item_body">11 Sep' 21</div>,
# ...

# %%
CTC=[]
for i in ctc:
    for j in i.find_all("i"):
        CTC.append(i.text.replace("\n",""))
    
CTC
# Out:
# ['  3 - 4 LPA                                                    ',
#  '  3 - 4.2 LPA                                                    ',
#  '  3 - 3.5 LPA                                                    ',
#  '  3 - 4 LPA                                                    ',
#  '  4 - 7.2 LPA                                                    ',
#  '  3 LPA                                                    ',
#  '  3 LPA                                                    ',
#  '  3.5 - 4 LPA                                                    ',
#  '  6 - 10 LPA                                                    ',
#  '  3 - 4 LPA                                                    ',
#  '  3 - 3.2 LPA                                                    ',
#  '  3 - 4 LPA                                                    ',
#  '  3 LPA                                                    ',
#  '  3 - 3.1 LPA                                                    ',
# ...

# %%
apply_date=Soup.find_all("div",class_="other_detail_item_row")
apply_date
# Out:
# [<div class="other_detail_item_row">
#  <div class="other_detail_item">
#  <div class="item_heading">
#  <i class="ic-16-play-circle"></i>
#  <span>
#                                  Start date
#                              </span>
#  </div>
#  <div class="item_body" id="start-date-first">
#  <span class="start_immediately_mobile">Starts </span>Immediately
#                          </div>
#  </div>
#  <div class="other_detail_item">
#  <div class="item_heading">
#  <i class="ic-16-money"></i>
#  <span>CTC</span>
#  </div>
#  <div class="item_body">
#  <i class="ic-16-currency-inr"></i>  3 - 4 LPA                                                    </div>
#  </div>
#  </div>,
#  <div class="other_detail_item_row">
#  <div class="other_detail_item">
#  <div class="item_heading">
#  <i class="ic-16-hourglass"></i>
#  <span>Apply By</span>
#  </div>
#  <div class="item_body">18 Sep' 21</div>
#  </div>
#  </div>,
#  <div class="other_detail_item_row">
#  <div class="other_detail_item">
# ...

# %%
Apply_date=[]
for i in apply_date:
    for j in i.find_all("div"):
        Apply_date.append(j.text)
    
Apply_date
# Out:
# ['\n\n\n\n                                Start date\n                            \n\n\nStarts\xa0Immediately\n                        \n',
#  '\n\n\n                                Start date\n                            \n',
#  '\nStarts\xa0Immediately\n                        ',
#  '\n\n\nCTC\n\n\n  3 - 4 LPA                                                    \n',
#  '\n\nCTC\n',
#  '\n  3 - 4 LPA                                                    ',
#  "\n\n\nApply By\n\n18 Sep' 21\n",
#  '\n\nApply By\n',
#  "18 Sep' 21",
#  '\n\n\n\n                                Start date\n                            \n\n\nStarts\xa0Immediately\n                        \n',
#  '\n\n\n                                Start date\n                            \n',
#  '\nStarts\xa0Immediately\n                        ',
#  '\n\n\nCTC\n\n\n  3 - 4.2 LPA                                                    \n',
#  '\n\nCTC\n',
#  '\n  3 - 4.2 LPA                                                    ',
# ...

# %%
import pandas as pd
job_details=pd.DataFrame({})
job_details['Job_title']=Job_title
job_details['Company_name']=Company_name
##job_details['Apply_date']=apply_date
##job_details['CTC']=CTC

job_detials
# Out:
#                                             Job_title  \
# 0                                  OMNI SPORT LEADER
# 1          Executive/Senior Executive - Partnerships
# 2                                  Executive - Sales
# 3                        Junior Operations Executive
# 4                          Student Success - Teacher
# 5                             Supply Chain Executive
# 6                                     Game Developer
# 7                       Associate - Digital Products
# 8    Program Impact In-charge (Science And Mathema...
# 9                          Software Engineer Trainee
# 10                                   Sales Executive
# 11                       Digital Marketing Executive
# 12                           Corporate Sales Manager
# 13                                Software Developer
# 14                   Executive Assistant To Director
# 15   C++ Embedded/Semiconductor Expert (SoC Modeli...
# 16                              Mobile App Developer
# ...

# %% [markdown]
# 10. Write a python program to scrape house details from https://www.nobroker.in/ for any location. It should
# include house title, location, area, emi and price

# %%
#importing the required libraries
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://www.nobroker.in/property/sale/delhi/multiple?searchParam=...&radius=2.0")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\n          <!DOCTYPE html><html lang="en"><head>\n          <meta property="fb:pages" content="794951570520699" />\n          <link rel="canonical" href="https://www.nobroker.in" />\n          \n          \n           \n          <link rel="shortcut icon" id="favicon" href="//assets.nobroker.in/static/img/favicon.png"/>\n          <link rel="apple-touch-icon" href="https://images.nobroker.in/static/img/fav64.png">\n          <meta charset="utf-8"/><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>\n          <meta name="google-play-app" content="app-id=com.nobroker.app&referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb">\n    \t    <meta name="apple-itunes-app" content="app-id=1200507100, app-argument=nobrokerapp://">\n          <meta name="theme-color" content="#fd3752">\n          <meta name="keywords" content="flats for rent, Apartments for rent, flats for sale, apartments for sale, Properties for rent, without broker, no brokerage, broker free rental pro
# ...

# %%
Soup=BeautifulSoup(page.content)   #scrape webpage
Soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# <meta content="flats for rent, Apartments for rent, flats for sale, apartments for sale, Properties for rent, without broker, no brokerage, broker free rental properties, flat, apartment, rent, rental, nobroker.in, Nobroker" name="keywords"/>
# ...

# %%
house_title=Soup.find_all("h2",class_="heading-6 font-semi-bold nb__1AShY")
house_title
# Out:
# [<h2 class="heading-6 font-semi-bold nb__1AShY"><span itemprop="name">3 BHK Flat  For Sale  In Bharat Vandana Apartment, Dwarka In Dwarka</span> <svg aria-hidden="true" class="jss1" focusable="false" role="presentation" viewbox="0 0 24 24"><path d="M0 0h24v24H0z" fill="none"></path><path d="M19 19H5V5h7V3H5c-1.11 0-2 .9-2 2v14c0 1.1.89 2 2 2h14c1.1 0 2-.9 2-2v-7h-2v7zM14 3v2h3.59l-9.83 9.83 1.41 1.41L19 6.41V10h2V3h-7z"></path></svg></h2>,
#  <h2 class="heading-6 font-semi-bold nb__1AShY"><span itemprop="name">1 BHK Flat  For Sale  In Dda Sec 23 Dwarka Delhi In Dwarka</span> <svg aria-hidden="true" class="jss1" focusable="false" role="presentation" viewbox="0 0 24 24"><path d="M0 0h24v24H0z" fill="none"></path><path d="M19 19H5V5h7V3H5c-1.11 0-2 .9-2 2v14c0 1.1.89 2 2 2h14c1.1 0 2-.9 2-2v-7h-2v7zM14 3v2h3.59l-9.83 9.83 1.41 1.41L19 6.41V10h2V3h-7z"></path></svg></h2>,
# ...

# %%
Title=[]
for i in house_title:
    Title.append(i.text)
    
Title
# Out:
# ['3 BHK Flat  For Sale  In Bharat Vandana Apartment, Dwarka In Dwarka ',
#  '1 BHK Flat  For Sale  In Dda Sec 23 Dwarka Delhi In Dwarka ',
#  '3 BHK Flat  For Sale  In Builder Floor, Bhagwati Garden Extn.  In Dwarka ',
#  '1 BHK Flat  For Sale  In Ashiana Residency In Dwarka ',
#  '3 BHK In Independent House  For Sale  In Dwarka ',
#  '2 BHK Flat  For Sale  In Dda Flats, Dwarka ,sector 19 B In Dwarka ',
#  '3 BHK In Independent House  For Sale  In Dwarka ',
#  '1 BHK Flat  For Sale  In Dwarka Mor In Dwarka ',
#  '3 BHK Flat  For Sale  In Delhi In Dwarka ',
#  '2 BHK Flat  For Sale  In Dwarka Mor ']

# %%
location=Soup.find_all("div",class_="nb__2CMjv")
location
# Out:
# [<div class="nb__2CMjv">Sec 6 market</div>,
#  <div class="nb__2CMjv">sec23 behind cng pump</div>,
#  <div class="nb__2CMjv">PLOT13B, Block C, Sewak Park near dwaraka mor</div>,
#  <div class="nb__2CMjv">110078</div>,
#  <div class="nb__2CMjv">metro</div>,
#  <div class="nb__2CMjv">Sector 19 b</div>,
#  <div class="nb__2CMjv">Dwarka sector 8 A Block</div>,
#  <div class="nb__2CMjv">Tara Nagar, Duggal Farm</div>,
#  <div class="nb__2CMjv">sector 1</div>,
#  <div class="nb__2CMjv">Standalone Building, Bhagwati Garden near Ram Medicos &amp; Cosmetic And Haryana Dairy</div>]

# %%
Location=[]
for i in location:
    Location.append(i.text)
    
Location
# Out:
# ['Sec 6 market',
#  'sec23 behind cng pump',
#  'PLOT13B, Block C, Sewak Park near dwaraka mor',
#  '110078',
#  'metro',
#  'Sector 19 b',
#  'Dwarka sector 8 A Block',
#  'Tara Nagar, Duggal Farm',
#  'sector 1',
#  'Standalone Building, Bhagwati Garden near Ram Medicos & Cosmetic And Haryana Dairy']

# %%
price=Soup.find_all("div",class_="font-semi-bold heading-6")
price
# Out:
# [<div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue"><meta content="Minimum Rent" itemprop="name"/><meta content="INR" itemprop="unitCode"/><div class="nb__3oNyC">1,000 sqft</div></div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>48,717/Month</div>,
#  <div class="font-semi-bold heading-6"><meta content="Minimum Deposit" itemprop="name"/><span>₹<!-- -->85 Lacs</span></div>,
#  <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue"><meta content="Minimum Rent" itemprop="name"/><meta content="INR" itemprop="unitCode"/><div class="nb__3oNyC">400 sqft</div></div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>16,048/Month</div>,
#  <div class="font-semi-bold heading-6"><meta content="Minimum Deposit" itemprop="name"/><span>₹<!-- -->28 Lacs</span></div>,
# ...

# %%
Price=[]
for i in price:
    for j in i.find_all("span"):
            Price.append(j.text)
    
Price
# Out:
# ['₹',
#  '₹85 Lacs',
#  '₹',
#  '₹28 Lacs',
#  '₹',
#  '₹58 Lacs',
#  '₹',
#  '₹20 Lacs',
#  '₹',
#  '₹60 Lacs',
#  '₹',
#  '₹1.26 Crores',
#  '₹',
#  '₹1.85 Crores',
#  '₹',
#  '₹17 Lacs',
#  '₹',
#  '₹1.35 Crores',
#  '₹',
#  '₹27 Lacs']

# %%
area=Soup.find_all("div",class_="font-semi-bold heading-6")
area
# Out:
# [<div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue"><meta content="Minimum Rent" itemprop="name"/><meta content="INR" itemprop="unitCode"/><div class="nb__3oNyC">1,000 sqft</div></div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>48,717/Month</div>,
#  <div class="font-semi-bold heading-6"><meta content="Minimum Deposit" itemprop="name"/><span>₹<!-- -->85 Lacs</span></div>,
#  <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue"><meta content="Minimum Rent" itemprop="name"/><meta content="INR" itemprop="unitCode"/><div class="nb__3oNyC">400 sqft</div></div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>16,048/Month</div>,
#  <div class="font-semi-bold heading-6"><meta content="Minimum Deposit" itemprop="name"/><span>₹<!-- -->28 Lacs</span></div>,
# ...

# %%
Area=[]
for i in area:
    for j in i.find_all("div"):
        Area.append(i.text)
    
Area
# Out:
# ['1,000 sqft',
#  '400 sqft',
#  '900 sqft',
#  '400 sqft',
#  '1,000 sqft',
#  '1,288 sqft',
#  '1,800 sqft',
#  '400 sqft',
#  '1,400 sqft',
#  '558 sqft']

# %%
emi=Soup.find_all("div",class_="font-semi-bold heading-6", id="roomType")
emi
# Out:
# [<div class="font-semi-bold heading-6" id="roomType"><span>₹</span>48,717/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>16,048/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>33,242/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>11,462/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>34,388/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>72,216/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>1.06 Lacs/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>9,743/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>77,374/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>15,474/Month</div>]

# %%
Emi=[]
for i in emi:
   ## for j in i.find_all("$0"):
        Emi.append(i.text)
    
Emi
# Out:
# ['₹48,717/Month',
#  '₹16,048/Month',
#  '₹33,242/Month',
#  '₹11,462/Month',
#  '₹34,388/Month',
#  '₹72,216/Month',
#  '₹1.06 Lacs/Month',
#  '₹9,743/Month',
#  '₹77,374/Month',
#  '₹15,474/Month']

# %%
import pandas as pd
import numpy as np
house_details=pd.DataFrame({})
house_details['Title']=house_title
house_details['Emi']=emi
##house_details['Price']=pd.Series([Price])  ## unable to print due to the index error
house_details['Location']=location
##house_details['Area']=pd.Series([Area])   ## unable to print due to the index error

house_details
# Out:
#                                                Title                     Emi  \
# 0  [[3 BHK Flat  For Sale  In Bharat Vandana Apar...     [[₹], 48,717/Month]
# 1  [[1 BHK Flat  For Sale  In Dda Sec 23 Dwarka D...     [[₹], 16,048/Month]
# 2  [[3 BHK Flat  For Sale  In Builder Floor, Bhag...     [[₹], 33,242/Month]
# 3  [[1 BHK Flat  For Sale  In Ashiana Residency I...     [[₹], 11,462/Month]
# 4  [[3 BHK In Independent House  For Sale  In Dwa...     [[₹], 34,388/Month]
# 5  [[2 BHK Flat  For Sale  In Dda Flats, Dwarka ,...     [[₹], 72,216/Month]
# 6  [[3 BHK In Independent House  For Sale  In Dwa...  [[₹], 1.06 Lacs/Month]
# 7  [[1 BHK Flat  For Sale  In Dwarka Mor In Dwark...      [[₹], 9,743/Month]
# 8  [[3 BHK Flat  For Sale  In Delhi In Dwarka],  ...     [[₹], 77,374/Month]
# 9  [[2 BHK Flat  For Sale  In Dwarka Mor],  , [[]...     [[₹], 15,474/Month]
#
#                                             Location
# 0                                     [Sec 6 market]
# ...
